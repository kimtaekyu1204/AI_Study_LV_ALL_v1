# %% [markdown]
# # LSTM
# LSTM (Long Short-Term Memory) : '단기기억'을 '오래' 기억하기

# %% [markdown]
# # IMDB 데이터 준비

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
from tensorflow import keras

import random
def set_seed(seed = 42):
  tf.keras.utils.set_random_seed(seed)
  tf.config.experimental.enable_op_determinism()

set_seed(42)

# %%
base_path = r'/content/drive/MyDrive/KoreaIT (코리아it)/250107 💚자연어처리/[AI자연어]/dataset(AI2501)/out'

# %%
# 이전 예제 처럼 IMDB  리뷰 데이터를 로드하고 훈련세트와 검증세트로 나눔
from tensorflow.keras.datasets import imdb
from sklearn.model_selection import train_test_split

(train_input, train_target), (test_input, test_target) = imdb.load_data(
    num_words=500)

train_input, val_input, train_target, val_target = train_test_split(
    train_input, train_target, test_size=0.2, random_state=42)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
max_len = 100

# %%
# ↓ 각 샘플의 길이를 100에 맞추고 부족할때는 패딩을 추가
train_seq = pad_sequences(train_input, maxlen=max_len)
val_seq = pad_sequences(val_input, maxlen=max_len)
test_seq = pad_sequences(test_input, maxlen=max_len)

# %% [markdown]
# # ■ LSTM
#
# **tf.keras.layers.LSTM**
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTM
#
# ```python
# tf.keras.layers.LSTM(
#     units,
#     activation='tanh',
#     recurrent_activation='sigmoid',
#     use_bias=True,
#     kernel_initializer='glorot_uniform',
#     recurrent_initializer='orthogonal',
#     bias_initializer='zeros',
#     unit_forget_bias=True,
#     kernel_regularizer=None,
#     recurrent_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     recurrent_constraint=None,
#     bias_constraint=None,
#     dropout=0.0,
#     recurrent_dropout=0.0,
#     seed=None,
#     return_sequences=False,
#     return_state=False,
#     go_backwards=False,
#     stateful=False,
#     unroll=False,
#     use_cudnn='auto',
#     **kwargs
# )
# ```

# %%
model = keras.Sequential()
model.add(keras.layers.Input(shape=(max_len,)))
model.add(keras.layers.Embedding(500, 16))
model.add(keras.layers.LSTM(units=8))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 8)              │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,809 (34.41 KB)
#  Trainable params: 8,809 (34.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
"""
Model: "sequential"
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
│ embedding (Embedding)           │ (None, 100, 16)        │         8,000 │


│ lstm (LSTM)                     │ (None, 8)              │           800 │
        # ①입력 parameter : 16 inputs x 8 units = 128개
        # ②은닉상태 param  : 8 x 8 = 64개
        # ③bias   :   8 개

        # ④: ① + ② + ③ = 200개

        # 전체 parameter 는
        #  4 x ④200개 => 800개.
          #  ↑ 4 는 LSTM 셀 내의 각 게이트 (입력 게이트, 출력 게이트, 포겟 게이트, 셀 상태 업데이트)
          #    에 해당하는 파라미터의 개수

        ★LSTM의 파라미터 개수★
            => 4gates x units x (units + inputs + 1)
            => ex) 4 x 8 x (8 + 16 + 1) => 800


│ dense (Dense)                   │ (None, 1)              │             9 │

 Total params: 8,809 (34.41 KB)
 Trainable params: 8,809 (34.41 KB)
 Non-trainable params: 0 (0.00 B)

"""
None

# %%
base_path = r'/content/drive/MyDrive/KoreaIT (코리아it)/250107 💚자연어처리/[AI자연어]/dataset(AI2501)/out'

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-lstm-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history = model.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5110 - loss: 0.6929 - val_accuracy: 0.5864 - val_loss: 0.6911
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5784 - loss: 0.6907 - val_accuracy: 0.6258 - val_loss: 0.6874
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6217 - loss: 0.6858 - val_accuracy: 0.6562 - val_loss: 0.6765
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6681 - loss: 0.6682 - val_accuracy: 0.7096 - val_loss: 0.6177
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7180 - loss: 0.6006 - val_accuracy: 0.7248 - val_loss: 0.5760
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7282 - loss: 0.5690 - val_accuracy: 0.7404 - val_loss: 0.5555
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7481 - loss: 0.5465 - val_accuracy: 0.7450 - val_loss: 0.5383
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7600 - loss: 0.5274 - val_accuracy: 0.7588 - val_loss: 0.5216
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7688 - loss: 0.5110 - val_accuracy: 0.7698 - val_loss: 0.5076
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7777 - loss: 0.4972 - val_accuracy: 0.7746 - val_loss: 0.4959
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7831 - loss: 0.4853 - val_accuracy: 0.7802 - val_loss: 0.4862
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7885 - loss: 0.4750 - val_accuracy: 0.7850 - val_loss: 0.4781
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7936 - loss: 0.4662 - val_accuracy: 0.7874 - val_loss: 0.4713
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7961 - loss: 0.4585 - val_accuracy: 0.7876 - val_loss: 0.4659
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8009 - loss: 0.4519 - val_accuracy: 0.7904 - val_loss: 0.4614
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8036 - loss: 0.4461 - val_accuracy: 0.7920 - val_loss: 0.4577
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8054 - loss: 0.4411 - val_accuracy: 0.7900 - val_loss: 0.4548
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8083 - loss: 0.4369 - val_accuracy: 0.7898 - val_loss: 0.4524
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8104 - loss: 0.4332 - val_accuracy: 0.7908 - val_loss: 0.4504
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8117 - loss: 0.4300 - val_accuracy: 0.7904 - val_loss: 0.4488
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8128 - loss: 0.4273 - val_accuracy: 0.7902 - val_loss: 0.4475
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8135 - loss: 0.4249 - val_accuracy: 0.7888 - val_loss: 0.4463
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8139 - loss: 0.4228 - val_accuracy: 0.7894 - val_loss: 0.4453
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8139 - loss: 0.4210 - val_accuracy: 0.7886 - val_loss: 0.4444
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8144 - loss: 0.4194 - val_accuracy: 0.7884 - val_loss: 0.4436
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8152 - loss: 0.4179 - val_accuracy: 0.7902 - val_loss: 0.4429
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8148 - loss: 0.4166 - val_accuracy: 0.7914 - val_loss: 0.4422
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8140 - loss: 0.4154 - val_accuracy: 0.7914 - val_loss: 0.4416
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8145 - loss: 0.4144 - val_accuracy: 0.7932 - val_loss: 0.4410
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8139 - loss: 0.4134 - val_accuracy: 0.7940 - val_loss: 0.4405
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8141 - loss: 0.4125 - val_accuracy: 0.7936 - val_loss: 0.4400
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8137 - loss: 0.4117 - val_accuracy: 0.7940 - val_loss: 0.4395
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8138 - loss: 0.4109 - val_accuracy: 0.7936 - val_loss: 0.4391
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8141 - loss: 0.4102 - val_accuracy: 0.7946 - val_loss: 0.4387
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8147 - loss: 0.4095 - val_accuracy: 0.7944 - val_loss: 0.4384
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8151 - loss: 0.4089 - val_accuracy: 0.7946 - val_loss: 0.4381
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8153 - loss: 0.4083 - val_accuracy: 0.7934 - val_loss: 0.4379
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8170 - loss: 0.4077 - val_accuracy: 0.7940 - val_loss: 0.4376
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8170 - loss: 0.4072 - val_accuracy: 0.7932 - val_loss: 0.4375
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8162 - loss: 0.4067 - val_accuracy: 0.7938 - val_loss: 0.4373
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8163 - loss: 0.4061 - val_accuracy: 0.7940 - val_loss: 0.4372
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8160 - loss: 0.4057 - val_accuracy: 0.7940 - val_loss: 0.4370
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8167 - loss: 0.4052 - val_accuracy: 0.7936 - val_loss: 0.4370
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8166 - loss: 0.4047 - val_accuracy: 0.7930 - val_loss: 0.4369
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8167 - loss: 0.4043 - val_accuracy: 0.7934 - val_loss: 0.4368
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8169 - loss: 0.4038 - val_accuracy: 0.7934 - val_loss: 0.4368
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8173 - loss: 0.4034 - val_accuracy: 0.7938 - val_loss: 0.4368
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8173 - loss: 0.4030 - val_accuracy: 0.7940 - val_loss: 0.4368
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8171 - loss: 0.4025 - val_accuracy: 0.7944 - val_loss: 0.4368
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8166 - loss: 0.4021 - val_accuracy: 0.7944 - val_loss: 0.4368
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8164 - loss: 0.4017 - val_accuracy: 0.7942 - val_loss: 0.4368
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8167 - loss: 0.4013 - val_accuracy: 0.7944 - val_loss: 0.4368

# %%
early_stopping_cb.best_epoch
# Out:
# 48

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # 순환층에 드롭아웃 적용

# %%
# 완전연결신경망과 CNN 에서는 Dropout 클래스를 사용해서 dropout 을 적용했었다
# 순환층은 '자체적으로 dropout 기능을 제공'

# SimpleRNN, LSTM 클래스에 제공하는 2개의 dropout 매개변수
#   dropout= : 셀의 '입력'에 dropout 적용
#   recurrent_dropout= : 순환되는 '은닉상태'에 dropout 적용
#                        ※ recurrent_dropout 는 GPU를 통한 훈련 못함..

#  아래 예제에선 dropout= 만 사용함..

# %%
model2 = keras.Sequential()
model2.add(keras.layers.Input(shape=(max_len,)))
model2.add(keras.layers.Embedding(500, 16))
model2.add(keras.layers.LSTM(units=8, dropout=0.3))  # dropout 30%
model2.add(keras.layers.Dense(1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 8)              │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,809 (34.41 KB)
#  Trainable params: 8,809 (34.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model2.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-dropout-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history2 = model2.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.5083 - loss: 0.6929 - val_accuracy: 0.5342 - val_loss: 0.6921
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5544 - loss: 0.6918 - val_accuracy: 0.5756 - val_loss: 0.6906
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5943 - loss: 0.6896 - val_accuracy: 0.6104 - val_loss: 0.6867
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6256 - loss: 0.6840 - val_accuracy: 0.6522 - val_loss: 0.6718
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6738 - loss: 0.6577 - val_accuracy: 0.6930 - val_loss: 0.6071
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7014 - loss: 0.5944 - val_accuracy: 0.7148 - val_loss: 0.5795
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.7215 - loss: 0.5701 - val_accuracy: 0.7304 - val_loss: 0.5571
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7443 - loss: 0.5457 - val_accuracy: 0.7350 - val_loss: 0.5436
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7536 - loss: 0.5286 - val_accuracy: 0.7524 - val_loss: 0.5235
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7659 - loss: 0.5122 - val_accuracy: 0.7666 - val_loss: 0.5079
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.7721 - loss: 0.4986 - val_accuracy: 0.7682 - val_loss: 0.5008
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7782 - loss: 0.4875 - val_accuracy: 0.7788 - val_loss: 0.4884
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7858 - loss: 0.4764 - val_accuracy: 0.7738 - val_loss: 0.4831
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7889 - loss: 0.4673 - val_accuracy: 0.7878 - val_loss: 0.4709
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7932 - loss: 0.4618 - val_accuracy: 0.7834 - val_loss: 0.4712
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7965 - loss: 0.4554 - val_accuracy: 0.7850 - val_loss: 0.4658
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7966 - loss: 0.4511 - val_accuracy: 0.7866 - val_loss: 0.4608
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7978 - loss: 0.4453 - val_accuracy: 0.7874 - val_loss: 0.4582
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8067 - loss: 0.4386 - val_accuracy: 0.7856 - val_loss: 0.4562
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8009 - loss: 0.4403 - val_accuracy: 0.7918 - val_loss: 0.4521
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8057 - loss: 0.4340 - val_accuracy: 0.7858 - val_loss: 0.4540
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8044 - loss: 0.4353 - val_accuracy: 0.7890 - val_loss: 0.4518
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8067 - loss: 0.4302 - val_accuracy: 0.7928 - val_loss: 0.4492
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8104 - loss: 0.4279 - val_accuracy: 0.7894 - val_loss: 0.4493
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8091 - loss: 0.4263 - val_accuracy: 0.7902 - val_loss: 0.4470
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8089 - loss: 0.4269 - val_accuracy: 0.7898 - val_loss: 0.4477
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8105 - loss: 0.4229 - val_accuracy: 0.7944 - val_loss: 0.4445
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8124 - loss: 0.4211 - val_accuracy: 0.7904 - val_loss: 0.4460
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8103 - loss: 0.4204 - val_accuracy: 0.7916 - val_loss: 0.4446
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8081 - loss: 0.4191 - val_accuracy: 0.7930 - val_loss: 0.4462

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # ■ 순환층 2개 연결하기
# ### 순환층 연결시 주의!
# - 순환층의 은닉상태는 샘플의 마지막 스텝에 대한 은닉 상태만 다음층으로 전달한다
# - 그러나, 순환층을 쌓게 되면 모든 순환층에는 순차 데이터가 필요하다.
# - 따라서
#     - 앞쪽의 순환층은 '모든 타임스텝'에 대한 은닉상태를 출력해야 하고,
#     - 마지막 순환층만 '마지막 타임스텝의 은닉상태'를 출력해야 한다

# %% [markdown]
# ## return_sequences=True
# 모든 타임스텝에 대한 은닉상태 출력 (2차원 출력)

# %%
model3 = keras.Sequential()
model3.add(keras.layers.Input(shape=(max_len,)))
model3.add(keras.layers.Embedding(500, 16))
model3.add(keras.layers.LSTM(units=8, dropout=0.3, return_sequences=True))
model3.add(keras.layers.LSTM(units=8, dropout=0.3))
model3.add(keras.layers.Dense(1, activation='sigmoid'))

model3.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 100, 8)         │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 8)              │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,353 (36.54 KB)
#  Trainable params: 9,353 (36.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
"""
Model: "sequential_3"
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
│ embedding_3 (Embedding)         │ (None, 100, 16)        │         8,000 │
├─────────────────────────────────┼────────────────────────┼───────────────┤
│ lstm_3 (LSTM)                   │ (None, 100, 8)         │           800 │
        # [출력크기]
        # 첫번째 LSTM 층이 모든 타입스텝 (100개) 의 은닉상태를 출력하기 때문에
        # 출력크기가 (?, 100, 8) 로 출력됨 (2차원 출력)

        # [첫번째 LSTM 의 parameter]
            => 4gates x units x (units + inputs + 1)
            => ex) 4 x 8 x (8 + 16 + 1) => 800


│ lstm_4 (LSTM)                   │ (None, 8)              │           544 │
        # [출력크기]
        # 마지막 LSTM 층의 출력크기는 마지막 타임스텝의 은닉상태만 출력하기 때문에
        # 출력크기가 (?, 8) 이다.

        # [두번째 LSTM 의 parameter]
        # 두 번째 LSTM의 경우, '첫 번째 LSTM의 출력'이 '두 번째 LSTM의 입력'이 됩니다.
        # 따라서 두 번째 LSTM의 입력 피처 수는 첫 번째 LSTM의 유닛 수와 동일
            => units x (units + inputs + 1)

       #  4 gates x 8 x (8 + 8 + 1) => 544

│ dense_2 (Dense)                 │ (None, 1)              │             9 │
└─────────────────────────────────┴────────────────────────┴───────────────┘
 Total params: 9,353 (36.54 KB)
 Trainable params: 9,353 (36.54 KB)
 Non-trainable params: 0 (0.00 B)

"""
None

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model3.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-2rnn-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history3 = model3.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.4988 - loss: 0.6931 - val_accuracy: 0.5272 - val_loss: 0.6929
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5298 - loss: 0.6927 - val_accuracy: 0.5560 - val_loss: 0.6920
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.5581 - loss: 0.6913 - val_accuracy: 0.6024 - val_loss: 0.6870
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6155 - loss: 0.6818 - val_accuracy: 0.6604 - val_loss: 0.6441
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6767 - loss: 0.6232 - val_accuracy: 0.7078 - val_loss: 0.5778
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7129 - loss: 0.5722 - val_accuracy: 0.7240 - val_loss: 0.5578
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7402 - loss: 0.5411 - val_accuracy: 0.7394 - val_loss: 0.5328
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7541 - loss: 0.5205 - val_accuracy: 0.7500 - val_loss: 0.5182
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7631 - loss: 0.5045 - val_accuracy: 0.7572 - val_loss: 0.5097
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7705 - loss: 0.4949 - val_accuracy: 0.7688 - val_loss: 0.4954
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7759 - loss: 0.4828 - val_accuracy: 0.7610 - val_loss: 0.5011
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7807 - loss: 0.4768 - val_accuracy: 0.7750 - val_loss: 0.4856
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7856 - loss: 0.4724 - val_accuracy: 0.7712 - val_loss: 0.4871
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7861 - loss: 0.4689 - val_accuracy: 0.7798 - val_loss: 0.4741
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7930 - loss: 0.4641 - val_accuracy: 0.7746 - val_loss: 0.4818
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7933 - loss: 0.4578 - val_accuracy: 0.7792 - val_loss: 0.4802
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7964 - loss: 0.4553 - val_accuracy: 0.7842 - val_loss: 0.4705
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7942 - loss: 0.4513 - val_accuracy: 0.7810 - val_loss: 0.4727
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7966 - loss: 0.4518 - val_accuracy: 0.7818 - val_loss: 0.4711
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7948 - loss: 0.4485 - val_accuracy: 0.7810 - val_loss: 0.4710

# %%
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # ■ GRU 신경망
# Gated Recurrent Unit
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/GRU
#
# ```python
# tf.keras.layers.GRU(
#     units,
#     activation='tanh',
#     recurrent_activation='sigmoid',
#     use_bias=True,
#     kernel_initializer='glorot_uniform',
#     recurrent_initializer='orthogonal',
#     bias_initializer='zeros',
#     kernel_regularizer=None,
#     recurrent_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     recurrent_constraint=None,
#     bias_constraint=None,
#     dropout=0.0,
#     recurrent_dropout=0.0,
#     seed=None,
#     return_sequences=False,
#     return_state=False,
#     go_backwards=False,
#     stateful=False,
#     unroll=False,
#     reset_after=True,
#     use_cudnn='auto',
#     **kwargs
# )
# ```

# %%
model4 = keras.Sequential()
model4.add(keras.layers.Input(shape=(max_len,)))
model4.add(keras.layers.Embedding(500, 16))
model4.add(keras.layers.GRU(units=8))
model4.add(keras.layers.Dense(1, activation='sigmoid'))

model4.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 8)              │           624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,633 (33.72 KB)
#  Trainable params: 8,633 (33.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
"""
Model: "sequential_4"
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
│ embedding_4 (Embedding)         │ (None, 100, 16)        │         8,000 │
├─────────────────────────────────┼────────────────────────┼───────────────┤
│ gru (GRU)                       │ (None, 8)              │           624 │

      # 입력 parameter : 16 inputs x 8 units = 128개
      # 은닉상태 param : 8 x 8 = 64개
      # bias 가 뉴런마다 : 8개

      # 합하면 200개
      # 이런셀이 3개  200 * 3 => 600개?

      # TF GRU 는 내부적으로 작은 셀마다 하나의 bias 가 추가됨.
      #  작은셀3개 x 8개 units = 24개.


│ dense_3 (Dense)                 │ (None, 1)              │             9 │
└─────────────────────────────────┴────────────────────────┴───────────────┘
 Total params: 8,633 (33.72 KB)
 Trainable params: 8,633 (33.72 KB)
 Non-trainable params: 0 (0.00 B)
"""
None

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model4.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-gru-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history4 = model4.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5027 - loss: 0.6929 - val_accuracy: 0.5314 - val_loss: 0.6922
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5577 - loss: 0.6912 - val_accuracy: 0.5606 - val_loss: 0.6902
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5765 - loss: 0.6888 - val_accuracy: 0.5808 - val_loss: 0.6872
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5947 - loss: 0.6853 - val_accuracy: 0.5900 - val_loss: 0.6829
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6075 - loss: 0.6801 - val_accuracy: 0.5990 - val_loss: 0.6768
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6183 - loss: 0.6728 - val_accuracy: 0.6122 - val_loss: 0.6685
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6281 - loss: 0.6629 - val_accuracy: 0.6254 - val_loss: 0.6575
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6451 - loss: 0.6498 - val_accuracy: 0.6420 - val_loss: 0.6428
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6551 - loss: 0.6324 - val_accuracy: 0.6576 - val_loss: 0.6230
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6762 - loss: 0.6087 - val_accuracy: 0.6896 - val_loss: 0.5947
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7070 - loss: 0.5734 - val_accuracy: 0.7266 - val_loss: 0.5476
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7411 - loss: 0.5194 - val_accuracy: 0.7518 - val_loss: 0.5053
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7623 - loss: 0.4886 - val_accuracy: 0.7642 - val_loss: 0.4886
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7753 - loss: 0.4741 - val_accuracy: 0.7726 - val_loss: 0.4779
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7834 - loss: 0.4629 - val_accuracy: 0.7762 - val_loss: 0.4701
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7903 - loss: 0.4540 - val_accuracy: 0.7798 - val_loss: 0.4645
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7975 - loss: 0.4474 - val_accuracy: 0.7844 - val_loss: 0.4602
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8008 - loss: 0.4424 - val_accuracy: 0.7862 - val_loss: 0.4569
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8021 - loss: 0.4385 - val_accuracy: 0.7878 - val_loss: 0.4545
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8050 - loss: 0.4354 - val_accuracy: 0.7874 - val_loss: 0.4529
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8065 - loss: 0.4328 - val_accuracy: 0.7896 - val_loss: 0.4518
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8078 - loss: 0.4306 - val_accuracy: 0.7904 - val_loss: 0.4511
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8083 - loss: 0.4286 - val_accuracy: 0.7922 - val_loss: 0.4504
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8092 - loss: 0.4269 - val_accuracy: 0.7928 - val_loss: 0.4498
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8096 - loss: 0.4254 - val_accuracy: 0.7926 - val_loss: 0.4492
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8102 - loss: 0.4240 - val_accuracy: 0.7924 - val_loss: 0.4487
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8111 - loss: 0.4228 - val_accuracy: 0.7912 - val_loss: 0.4482
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8112 - loss: 0.4217 - val_accuracy: 0.7924 - val_loss: 0.4477
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8110 - loss: 0.4207 - val_accuracy: 0.7920 - val_loss: 0.4473
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8109 - loss: 0.4198 - val_accuracy: 0.7916 - val_loss: 0.4469
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8111 - loss: 0.4189 - val_accuracy: 0.7914 - val_loss: 0.4465
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8112 - loss: 0.4182 - val_accuracy: 0.7908 - val_loss: 0.4461
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8115 - loss: 0.4174 - val_accuracy: 0.7908 - val_loss: 0.4458
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8117 - loss: 0.4167 - val_accuracy: 0.7906 - val_loss: 0.4454
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8120 - loss: 0.4161 - val_accuracy: 0.7908 - val_loss: 0.4451
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8124 - loss: 0.4155 - val_accuracy: 0.7918 - val_loss: 0.4447
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8129 - loss: 0.4149 - val_accuracy: 0.7920 - val_loss: 0.4444
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8134 - loss: 0.4143 - val_accuracy: 0.7908 - val_loss: 0.4441
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8134 - loss: 0.4137 - val_accuracy: 0.7914 - val_loss: 0.4437
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8138 - loss: 0.4132 - val_accuracy: 0.7908 - val_loss: 0.4434
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8141 - loss: 0.4127 - val_accuracy: 0.7920 - val_loss: 0.4431
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8157 - loss: 0.4122 - val_accuracy: 0.7928 - val_loss: 0.4428
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8160 - loss: 0.4117 - val_accuracy: 0.7922 - val_loss: 0.4425
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8164 - loss: 0.4112 - val_accuracy: 0.7928 - val_loss: 0.4422
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8168 - loss: 0.4107 - val_accuracy: 0.7928 - val_loss: 0.4419
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8165 - loss: 0.4103 - val_accuracy: 0.7934 - val_loss: 0.4416
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8166 - loss: 0.4098 - val_accuracy: 0.7942 - val_loss: 0.4414
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8162 - loss: 0.4094 - val_accuracy: 0.7940 - val_loss: 0.4411
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8164 - loss: 0.4089 - val_accuracy: 0.7942 - val_loss: 0.4408
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8167 - loss: 0.4085 - val_accuracy: 0.7948 - val_loss: 0.4405
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8169 - loss: 0.4081 - val_accuracy: 0.7954 - val_loss: 0.4403
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8171 - loss: 0.4076 - val_accuracy: 0.7950 - val_loss: 0.4400
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8176 - loss: 0.4072 - val_accuracy: 0.7948 - val_loss: 0.4398
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8176 - loss: 0.4068 - val_accuracy: 0.7948 - val_loss: 0.4395
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8180 - loss: 0.4064 - val_accuracy: 0.7948 - val_loss: 0.4393
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8180 - loss: 0.4060 - val_accuracy: 0.7950 - val_loss: 0.4390
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8173 - loss: 0.4056 - val_accuracy: 0.7948 - val_loss: 0.4388
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.8172 - loss: 0.4052 - val_accuracy: 0.7954 - val_loss: 0.4386
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8173 - loss: 0.4048 - val_accuracy: 0.7952 - val_loss: 0.4383
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8172 - loss: 0.4044 - val_accuracy: 0.7956 - val_loss: 0.4381
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8173 - loss: 0.4040 - val_accuracy: 0.7956 - val_loss: 0.4379
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8172 - loss: 0.4036 - val_accuracy: 0.7954 - val_loss: 0.4377
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8174 - loss: 0.4032 - val_accuracy: 0.7958 - val_loss: 0.4375
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8180 - loss: 0.4028 - val_accuracy: 0.7960 - val_loss: 0.4373
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8177 - loss: 0.4024 - val_accuracy: 0.7964 - val_loss: 0.4371
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8180 - loss: 0.4020 - val_accuracy: 0.7964 - val_loss: 0.4369
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8181 - loss: 0.4017 - val_accuracy: 0.7956 - val_loss: 0.4367
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8182 - loss: 0.4013 - val_accuracy: 0.7956 - val_loss: 0.4365
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8185 - loss: 0.4009 - val_accuracy: 0.7948 - val_loss: 0.4363
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8185 - loss: 0.4005 - val_accuracy: 0.7952 - val_loss: 0.4362
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8187 - loss: 0.4002 - val_accuracy: 0.7938 - val_loss: 0.4360
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8190 - loss: 0.3998 - val_accuracy: 0.7934 - val_loss: 0.4358
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8192 - loss: 0.3994 - val_accuracy: 0.7936 - val_loss: 0.4357
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8191 - loss: 0.3991 - val_accuracy: 0.7932 - val_loss: 0.4355
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8190 - loss: 0.3987 - val_accuracy: 0.7936 - val_loss: 0.4354
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8190 - loss: 0.3984 - val_accuracy: 0.7944 - val_loss: 0.4352
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8195 - loss: 0.3980 - val_accuracy: 0.7944 - val_loss: 0.4351
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8196 - loss: 0.3977 - val_accuracy: 0.7950 - val_loss: 0.4349
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8201 - loss: 0.3973 - val_accuracy: 0.7958 - val_loss: 0.4348
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8207 - loss: 0.3970 - val_accuracy: 0.7966 - val_loss: 0.4347
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8207 - loss: 0.3966 - val_accuracy: 0.7970 - val_loss: 0.4345
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8211 - loss: 0.3963 - val_accuracy: 0.7962 - val_loss: 0.4344
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8210 - loss: 0.3959 - val_accuracy: 0.7960 - val_loss: 0.4343
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8217 - loss: 0.3956 - val_accuracy: 0.7960 - val_loss: 0.4342
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8218 - loss: 0.3952 - val_accuracy: 0.7958 - val_loss: 0.4341
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8224 - loss: 0.3949 - val_accuracy: 0.7960 - val_loss: 0.4340
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8226 - loss: 0.3945 - val_accuracy: 0.7970 - val_loss: 0.4339
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8231 - loss: 0.3942 - val_accuracy: 0.7976 - val_loss: 0.4338
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8227 - loss: 0.3939 - val_accuracy: 0.7978 - val_loss: 0.4337
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8226 - loss: 0.3935 - val_accuracy: 0.7978 - val_loss: 0.4336
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8227 - loss: 0.3932 - val_accuracy: 0.7980 - val_loss: 0.4335
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8226 - loss: 0.3929 - val_accuracy: 0.7982 - val_loss: 0.4334
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8229 - loss: 0.3925 - val_accuracy: 0.7988 - val_loss: 0.4333
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8230 - loss: 0.3922 - val_accuracy: 0.7990 - val_loss: 0.4332
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8232 - loss: 0.3919 - val_accuracy: 0.7990 - val_loss: 0.4331
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8237 - loss: 0.3915 - val_accuracy: 0.7996 - val_loss: 0.4330
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8236 - loss: 0.3912 - val_accuracy: 0.8000 - val_loss: 0.4330
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8238 - loss: 0.3909 - val_accuracy: 0.8008 - val_loss: 0.4329
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8238 - loss: 0.3906 - val_accuracy: 0.8002 - val_loss: 0.4328
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8240 - loss: 0.3902 - val_accuracy: 0.8006 - val_loss: 0.4327

# %%
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %%
# 테스트셋 평가
rnn_model = keras.models.load_model(os.path.join(base_path, 'best-gru-model.keras'))
rnn_model.evaluate(test_seq, test_target)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8030 - loss: 0.4304
# [0.429179847240448, 0.8023599982261658]

# %% [markdown]
# # ■ 양방향 LSTM
# Bidirectional-LSTM, Bi-LSTM
# RNN 이나 LSTM 은 일반 신경망과 다르게 시퀀스 또는 시계열 데이터 처리에 특화되어 은닉층에서 과거의 정보를 기억할 수 있습니다.  그러나, 순환 신경망의 구조적 특성상 데이터가 **'입력 순'** 으로 처리되기 때문에 이전 시점의 정보만 활용할 수 밖에 없는 단점이 존재합니다.  문장이 길어 질수록(시퀀스가 길어질수록) 성능이 저하될 수 밖에 없습니다. 다음 예문을 봅시다
#
# > ios 앱 <u>[   ]</u>은 맥북이 필요합니다
#
# > ios 앱 <u>개발</u>은 맥북이 필요합니다
#
# 한국어를 사용하는 우리에겐 어렵지 않게 빈칸에 들어가는 단어를 유추해낼수 있다.  그러나 일반적인 RNN 이나 LSTM 에서 순차적으로 입력되는 시퀀스를 통해 앞에 입력된 데이터인 'ios' 와 '앱' 이라는 단어만 가지고 빈칸에 들어갈 '개발' 이라는 단어를 유추해 내기엔 정보가 매우 부족하다.
#
# 문장 **앞부분보단, 뒷부분에 중요한 정보**가 존재하기 때문입니다.
#
# 따라서! 자연어 처리에서 입력 데이터의 '정방향' 처리만큼 **'역방향'** 처리도 중요합니다!
#
# **양방향 LSTM (Bidirectional LSTM)** 은 기존 LSTM 계측에 역방향으로 처리하는  LSTM 계층을 하나 더 추가해 양방향에서 문장의 패턴을 분석할수 있도록 구성되어 있습니다.  입력 문장을 양방향에서 처리하므로 시퀀스 길이가 길어진다 하더라도 정보 손실 없이 처리가 가능
#
#
# **양방향 LSTM 구조**
#
# ![](https://blog.kakaocdn.net/dn/ySdrH/btrZrwllBAV/T6RqmCYAkavMJ1iZ2gTi80/img.png)

# %% [markdown]
# ## Bidirectional
# **tf.keras.layers.Bidirectional**
# - RNN 에 적용하는 양방향 (bidirectional) wrapper
# - https://www.tensorflow.org/api_docs/python/tf/keras/layers/Bidirectional
# - Bidirectional 로 설정할 RNN layer 는 **return_sequences=True**: 모든 time step 에서 출력을 반환해야 하므로 설정해야 한다
#
# ```python
# tf.keras.layers.Bidirectional(
#     layer,
#     merge_mode='concat',
#     weights=None,
#     backward_layer=None,
#     **kwargs
# )
# ```

# %% [markdown]
# ## TimeDistributed
# **tf.keras.layers.TimeDistributed**
# - 각 time step 에서 출력된 output 을 내부에 선언해준 레이어와 연결시켜주는 역할
# - TimeDistributed 또한 Wrapper 다 (Wrapper 상속객체)
# - https://www.tensorflow.org/api_docs/python/tf/keras/layers/TimeDistributed
# - 출력 형태는 (batch_size, time_steps, num_classes)
#
# ```python
# tf.keras.layers.TimeDistributed(
#     layer, **kwargs
# )
# ```

# %% [markdown]
# 양방향 LSTM 모델을 정의할때 주의점!
# - 정방향, 역방향 LSTM 계측 모두 출력값을 연결해야 하기 때문에, return_sequences 인자를 반드시 True 로 해야 함.
# - 또한 Dense 계층을 TimeDistributed 래퍼를 사용해 3차원 텐서를 입력받을수 있게 확장해야 한다

# %% [markdown]
# ## 모델 정의

# %%
from tensorflow.keras.layers import Bidirectional, Embedding, \
                Input, LSTM, TimeDistributed, Dense, Flatten

# %%
model5 = keras.Sequential()

model5.add(Input(shape=(max_len,)))  # (100,)
model5.add(Embedding(input_dim=500, output_dim=16))
model5.add(Bidirectional(LSTM(8, dropout=0.3, return_sequences=True)))
model5.add(TimeDistributed(Dense(1, activation='sigmoid')))
model5.add(Flatten())
model5.add(Dense(1, activation='sigmoid'))

model5.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_6 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 100, 16)        │         1,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 100, 1)         │            17 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,718 (37.96 KB)
#  Trainable params: 9,718 (37.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model5.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-biLSTM-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history5 = model5.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 29ms/step - accuracy: 0.5033 - loss: 0.6942 - val_accuracy: 0.5126 - val_loss: 0.6931
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.5006 - loss: 0.6932 - val_accuracy: 0.5114 - val_loss: 0.6931
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4993 - loss: 0.6932 - val_accuracy: 0.5088 - val_loss: 0.6931
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5011 - loss: 0.6932 - val_accuracy: 0.5108 - val_loss: 0.6931
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4992 - loss: 0.6932 - val_accuracy: 0.5132 - val_loss: 0.6931
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5060 - val_loss: 0.6931
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.5029 - loss: 0.6932 - val_accuracy: 0.5146 - val_loss: 0.6930
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.5048 - loss: 0.6931 - val_accuracy: 0.5156 - val_loss: 0.6930
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.5048 - loss: 0.6931 - val_accuracy: 0.5142 - val_loss: 0.6930
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.5061 - loss: 0.6931 - val_accuracy: 0.5114 - val_loss: 0.6930
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5076 - loss: 0.6930 - val_accuracy: 0.5120 - val_loss: 0.6930
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.5058 - loss: 0.6930 - val_accuracy: 0.5116 - val_loss: 0.6930
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.5069 - loss: 0.6930 - val_accuracy: 0.5168 - val_loss: 0.6929
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.5105 - loss: 0.6929 - val_accuracy: 0.5214 - val_loss: 0.6929
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.5100 - loss: 0.6929 - val_accuracy: 0.5196 - val_loss: 0.6928
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.5139 - loss: 0.6928 - val_accuracy: 0.5248 - val_loss: 0.6928
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.5156 - loss: 0.6928 - val_accuracy: 0.5202 - val_loss: 0.6928
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.5179 - loss: 0.6927 - val_accuracy: 0.5222 - val_loss: 0.6927
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.5205 - loss: 0.6926 - val_accuracy: 0.5284 - val_loss: 0.6926
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.5285 - loss: 0.6925 - val_accuracy: 0.5278 - val_loss: 0.6925
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.5266 - loss: 0.6923 - val_accuracy: 0.5234 - val_loss: 0.6924
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.5351 - loss: 0.6921 - val_accuracy: 0.5354 - val_loss: 0.6922
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.5386 - loss: 0.6917 - val_accuracy: 0.5404 - val_loss: 0.6916
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5483 - loss: 0.6911 - val_accuracy: 0.5478 - val_loss: 0.6911
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.5611 - loss: 0.6902 - val_accuracy: 0.5504 - val_loss: 0.6898
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.5736 - loss: 0.6883 - val_accuracy: 0.5798 - val_loss: 0.6862
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5886 - loss: 0.6850 - val_accuracy: 0.6116 - val_loss: 0.6792
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6172 - loss: 0.6780 - val_accuracy: 0.6372 - val_loss: 0.6708
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.6446 - loss: 0.6682 - val_accuracy: 0.6564 - val_loss: 0.6583
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6590 - loss: 0.6552 - val_accuracy: 0.6704 - val_loss: 0.6432
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.6765 - loss: 0.6393 - val_accuracy: 0.6876 - val_loss: 0.6259
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.6947 - loss: 0.6223 - val_accuracy: 0.7000 - val_loss: 0.6059
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.7103 - loss: 0.5991 - val_accuracy: 0.7190 - val_loss: 0.5823
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7317 - loss: 0.5701 - val_accuracy: 0.7326 - val_loss: 0.5510
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7494 - loss: 0.5353 - val_accuracy: 0.7522 - val_loss: 0.5247
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7645 - loss: 0.5128 - val_accuracy: 0.7602 - val_loss: 0.5035
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7728 - loss: 0.4969 - val_accuracy: 0.7678 - val_loss: 0.4965
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7795 - loss: 0.4856 - val_accuracy: 0.7750 - val_loss: 0.4819
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7848 - loss: 0.4738 - val_accuracy: 0.7746 - val_loss: 0.4810
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.7876 - loss: 0.4675 - val_accuracy: 0.7776 - val_loss: 0.4707
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7918 - loss: 0.4615 - val_accuracy: 0.7820 - val_loss: 0.4684
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7920 - loss: 0.4568 - val_accuracy: 0.7804 - val_loss: 0.4691
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.7964 - loss: 0.4531 - val_accuracy: 0.7866 - val_loss: 0.4621
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7979 - loss: 0.4491 - val_accuracy: 0.7892 - val_loss: 0.4609
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8003 - loss: 0.4438 - val_accuracy: 0.7878 - val_loss: 0.4596
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8013 - loss: 0.4405 - val_accuracy: 0.7908 - val_loss: 0.4574
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8029 - loss: 0.4381 - val_accuracy: 0.7874 - val_loss: 0.4591
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.8060 - loss: 0.4364 - val_accuracy: 0.7894 - val_loss: 0.4552
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8060 - loss: 0.4307 - val_accuracy: 0.7882 - val_loss: 0.4547
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8080 - loss: 0.4309 - val_accuracy: 0.7880 - val_loss: 0.4516
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8036 - loss: 0.4297 - val_accuracy: 0.7924 - val_loss: 0.4512
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8076 - loss: 0.4285 - val_accuracy: 0.7952 - val_loss: 0.4467
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8124 - loss: 0.4220 - val_accuracy: 0.7940 - val_loss: 0.4487
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8085 - loss: 0.4214 - val_accuracy: 0.7902 - val_loss: 0.4516
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8131 - loss: 0.4201 - val_accuracy: 0.7968 - val_loss: 0.4418
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8110 - loss: 0.4190 - val_accuracy: 0.7960 - val_loss: 0.4425
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.8123 - loss: 0.4160 - val_accuracy: 0.7978 - val_loss: 0.4401
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8135 - loss: 0.4183 - val_accuracy: 0.7948 - val_loss: 0.4448
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.8150 - loss: 0.4126 - val_accuracy: 0.7974 - val_loss: 0.4441
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.8169 - loss: 0.4110 - val_accuracy: 0.7988 - val_loss: 0.4407

# %%
plt.plot(history5.history['loss'])
plt.plot(history5.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
