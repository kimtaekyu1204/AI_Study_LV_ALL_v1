# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print("Good Morning")
print(1000)
print(55 - 31)
print(3.14 + 1.1)
# Out:
# Good Morning
# 1000
# 24
# 4.24

# %%
"Good Morning"
# Out:
# 'Good Morning'

# %%
100 + 200 - 10
# Out:
# 290

# %%
300 * 5
# Out:
# 1500

# %%
800 / 4
# Out:
# 200.0

# %%
10 * (4 - 2)
# Out:
# 20

# %%
100 - 200
# Out:
# -100

# %%
print("Good Morning")
print(1000)
print(55 - 31)
print(3.14 + 1.1)
# Out:
# Good Morning
# 1000
# 24
# 4.24

# %%
"안녕하세요 여러분!"
# Out:
# '안녕하세요 여러분!'

# %%
"안녕하세요 여러분!"
# Out:
# '안녕하세요 여러분!'

# %%
800 / (4 - 2)
# Out:
# 400.0

# %%
10 * (4 - 2)
# Out:
# 20

# %%
100 - 200
# Out:
# -100

# %% [markdown]
# 안녕하세요 텍스트 셀입니다

# %%
20 - 40
# Out:
# -20
